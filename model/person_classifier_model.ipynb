# %% [markdown]
# # Celebrity Image Classification

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\mahmud\appdata\local\programs\python\python313\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\mahmud\appdata\local\programs\python\python313\lib\site-packages (from opencv-python) (2.2.2)

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### (1) Preprocessing: Detect face and eyes

# %% [markdown]
# ##### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.

# %% [markdown]
# Now how do you detect face and eyes?

# %%
img = cv2.imread('./test_images/mizanur_rahman.jpg')
img.shape
# Out:
# (617, 497, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (617, 497)

# %%
gray
# Out:
# array([[  7,   7,   7, ...,   7,   7,   7],
#        [  7,   7,   7, ...,   7,   7,   7],
#        [  7,   7,   7, ...,   7,   7,   7],
#        ...,
#        [103,  86,  91, ...,   0,   0,   0],
#        [111,  98, 105, ...,   0,   0,   0],
#        [105, 102, 106, ...,   0,   0,   0]], shape=(617, 497), dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ###### open cv documentation google it

# %%
import cv2

# Load face and eye cascades using OpenCV's built-in paths
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Check if cascades loaded correctly
if face_cascade.empty():
    raise IOError('Could not load face cascade.')
if eye_cascade.empty():
    raise IOError('Could not load eye cascade.')

# Now proceed with face detection
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
faces
# Out:
# array([[108, 113, 343, 343]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(108), np.int32(113), np.int32(343), np.int32(343))

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# (2) Preprocessing: Crop the facial region of the image

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (343, 343, 3)

# %% [markdown]
# (3) Preprocessing: Use wavelet transform as a feature for traning our model

# %% [markdown]
# ###### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# Wavelet transform

# %%
# !pip install PyWavelets
# Out:
# Requirement already satisfied: PyWavelets in c:\users\mahmud\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\mahmud\appdata\local\programs\python\python313\lib\site-packages (from PyWavelets) (2.2.2)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# ##### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region

# %% [markdown]
# ###### Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/mizanur_rahman.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/mizanur_rahman.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
org_image_obstructed = cv2.imread('./test_images/dr_younus.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/dr_younus.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[177, 173, 172],
#         [177, 173, 172],
#         [177, 173, 172],
#         ...,
#         [ 91, 118, 185],
#         [ 96, 122, 192],
#         [ 98, 124, 194]],
#
#        [[178, 174, 173],
#         [178, 174, 173],
#         [178, 174, 173],
#         ...,
#         [ 97, 124, 191],
#         [103, 129, 199],
#         [105, 131, 201]],
#
#        [[177, 173, 172],
#         [177, 173, 172],
#         [177, 173, 172],
#         ...,
#         [102, 128, 198],
#         [ 98, 123, 195],
#         [102, 127, 199]],
#
#        ...,
#
#        [[167, 163, 162],
#         [168, 164, 163],
#         [169, 165, 164],
#         ...,
#         [ 50,  81, 136],
#         [ 51,  81, 138],
#         [ 51,  84, 140]],
#
#        [[167, 163, 162],
#         [168, 164, 163],
#         [169, 165, 164],
#         ...,
#         [ 54,  85, 140],
#         [ 52,  82, 139],
#         [ 54,  84, 141]],
#
#        [[167, 162, 163],
#         [166, 161, 162],
#         [169, 164, 165],
#         ...,
#         [ 52,  83, 138],
#         [ 50,  80, 137],
#         [ 55,  84, 141]]], shape=(293, 293, 3), dtype=uint8)

# %% [markdown]
# Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/dr_muhammad_yunus',
#  './dataset/mizanur_rahman',
#  './dataset/sabur_khan',
#  './dataset/tarek_rahman',
#  './dataset/ziaur_rahman']

# %% [markdown]
# Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        if not entry.is_file():  # Skip directories
            continue
        
        try:
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            if roi_color is not None:
                cropped_folder = os.path.join(path_to_cr_data, celebrity_name)
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print(f"Generating cropped images in folder: {cropped_folder}")
                
                cropped_file_name = f"{celebrity_name}{count}.png"
                cropped_file_path = os.path.join(cropped_folder, cropped_file_name)
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
                count += 1
        except Exception as e:
            print(f"Error processing {entry.path}: {e}")
            continue
# Out:
# Generating cropped images in folder: ./dataset/cropped/dr_muhammad_yunus
# Generating cropped images in folder: ./dataset/cropped/mizanur_rahman
# Generating cropped images in folder: ./dataset/cropped/sabur_khan
# Generating cropped images in folder: ./dataset/cropped/tarek_rahman
# Generating cropped images in folder: ./dataset/cropped/ziaur_rahman

# %% [markdown]
# Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ###### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'dr_muhammad_yunus': ['./dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus1.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus10.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus11.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus12.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus13.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus14.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus15.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus16.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus17.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus18.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus19.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus2.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus20.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus21.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus22.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus23.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus24.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus25.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus26.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus27.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus28.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus29.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus3.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus30.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus31.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus32.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus33.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus34.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus35.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus36.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus37.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus38.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus39.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus4.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus40.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus41.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus42.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus43.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus44.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus45.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus46.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus47.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus5.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus6.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus7.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus8.png',
#   './dataset/cropped/dr_muhammad_yunus\\dr_muhammad_yunus9.png'],
#  'mizanur_rahman': ['./dataset/cropped/mizanur_rahman\\mizanur_rahman1.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman10.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman11.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman12.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman13.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman14.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman15.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman16.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman17.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman18.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman19.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman2.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman20.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman21.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman22.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman23.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman24.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman25.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman26.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman27.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman28.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman29.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman3.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman30.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman31.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman32.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman33.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman34.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman35.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman36.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman37.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman38.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman39.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman4.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman40.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman41.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman42.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman43.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman44.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman45.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman46.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman47.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman48.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman49.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman5.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman50.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman51.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman52.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman53.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman54.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman55.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman6.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman7.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman8.png',
#   './dataset/cropped/mizanur_rahman\\mizanur_rahman9.png'],
#  'sabur_khan': ['./dataset/cropped/sabur_khan\\sabur_khan1.png',
#   './dataset/cropped/sabur_khan\\sabur_khan10.png',
#   './dataset/cropped/sabur_khan\\sabur_khan11.png',
#   './dataset/cropped/sabur_khan\\sabur_khan12.png',
#   './dataset/cropped/sabur_khan\\sabur_khan13.png',
#   './dataset/cropped/sabur_khan\\sabur_khan14.png',
#   './dataset/cropped/sabur_khan\\sabur_khan15.png',
#   './dataset/cropped/sabur_khan\\sabur_khan16.png',
#   './dataset/cropped/sabur_khan\\sabur_khan17.png',
#   './dataset/cropped/sabur_khan\\sabur_khan18.png',
#   './dataset/cropped/sabur_khan\\sabur_khan19.png',
#   './dataset/cropped/sabur_khan\\sabur_khan2.png',
#   './dataset/cropped/sabur_khan\\sabur_khan20.png',
#   './dataset/cropped/sabur_khan\\sabur_khan21.png',
#   './dataset/cropped/sabur_khan\\sabur_khan22.png',
#   './dataset/cropped/sabur_khan\\sabur_khan23.png',
#   './dataset/cropped/sabur_khan\\sabur_khan24.png',
#   './dataset/cropped/sabur_khan\\sabur_khan25.png',
#   './dataset/cropped/sabur_khan\\sabur_khan26.png',
#   './dataset/cropped/sabur_khan\\sabur_khan27.png',
#   './dataset/cropped/sabur_khan\\sabur_khan28.png',
#   './dataset/cropped/sabur_khan\\sabur_khan29.png',
#   './dataset/cropped/sabur_khan\\sabur_khan3.png',
#   './dataset/cropped/sabur_khan\\sabur_khan30.png',
#   './dataset/cropped/sabur_khan\\sabur_khan31.png',
#   './dataset/cropped/sabur_khan\\sabur_khan32.png',
#   './dataset/cropped/sabur_khan\\sabur_khan33.png',
#   './dataset/cropped/sabur_khan\\sabur_khan34.png',
#   './dataset/cropped/sabur_khan\\sabur_khan35.png',
#   './dataset/cropped/sabur_khan\\sabur_khan36.png',
#   './dataset/cropped/sabur_khan\\sabur_khan37.png',
#   './dataset/cropped/sabur_khan\\sabur_khan4.png',
#   './dataset/cropped/sabur_khan\\sabur_khan5.png',
#   './dataset/cropped/sabur_khan\\sabur_khan6.png',
#   './dataset/cropped/sabur_khan\\sabur_khan7.png',
#   './dataset/cropped/sabur_khan\\sabur_khan8.png',
#   './dataset/cropped/sabur_khan\\sabur_khan9.png'],
#  'tarek_rahman': ['./dataset/cropped/tarek_rahman\\tarek_rahman1.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman10.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman11.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman12.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman13.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman14.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman15.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman16.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman17.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman18.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman19.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman2.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman20.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman21.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman22.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman23.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman24.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman25.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman26.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman27.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman28.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman29.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman3.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman30.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman31.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman32.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman33.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman34.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman35.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman36.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman37.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman38.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman39.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman4.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman40.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman41.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman42.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman43.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman44.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman45.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman46.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman5.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman6.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman7.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman8.png',
#   './dataset/cropped/tarek_rahman\\tarek_rahman9.png'],
#  'ziaur_rahman': ['./dataset/cropped/ziaur_rahman\\ziaur_rahman1.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman10.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman11.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman12.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman13.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman14.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman15.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman16.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman17.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman18.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman19.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman2.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman20.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman21.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman22.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman23.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman24.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman25.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman26.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman27.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman28.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman29.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman3.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman30.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman31.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman32.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman33.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman34.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman35.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman36.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman37.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman38.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman39.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman4.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman40.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman5.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman6.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman7.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman8.png',
#   './dataset/cropped/ziaur_rahman\\ziaur_rahman9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'dr_muhammad_yunus': 0,
#  'mizanur_rahman': 1,
#  'sabur_khan': 2,
#  'tarek_rahman': 3,
#  'ziaur_rahman': 4}

# %% [markdown]
# #### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            print(f"Error: Unable to read image at {training_image}")
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 85],
#        [111],
#        [ 15],
#        ...,
#        [ 23],
#        [  0],
#        [254]], shape=(4096, 1), dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (225, 4096)

# %% [markdown]
# Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# #### We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8771929824561403

# %%
len(X_test)
# Out:
# 57

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        10
#            1       1.00      0.92      0.96        12
#            2       1.00      0.91      0.95        11
#            3       1.00      0.81      0.90        16
#            4       0.67      1.00      0.80         8
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.89      0.87        57
# weighted avg       0.91      0.88      0.88        57

# %% [markdown]
# #### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\MAHMUD\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.898752
# 1        random_forest    0.768984
# 2  logistic_regression    0.916756
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9298245614035088

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7017543859649122

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9122807017543859

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 9,  0,  0,  0,  1],
#        [ 0, 11,  0,  0,  1],
#        [ 1,  0, 10,  0,  0],
#        [ 0,  0,  0, 15,  1],
#        [ 0,  0,  0,  0,  8]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'dr_muhammad_yunus': 0,
#  'mizanur_rahman': 1,
#  'sabur_khan': 2,
#  'tarek_rahman': 3,
#  'ziaur_rahman': 4}

# %% [markdown]
# # Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\mahmud\appdata\local\programs\python\python313\lib\site-packages (1.4.2)
# ['saved_model.pkl']

# %% [markdown]
# Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
